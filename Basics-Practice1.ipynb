# %% [markdown]
# # Using Numpy, Pandas, Matplotlib & Seaborn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=np.array([9.65,8.87,8,8.67,8.21,9.34,8.2,7.9,8,8.6])

# %%
print(a)
# Out:
# [9.65 8.87 8.   8.67 8.21 9.34 8.2  7.9  8.   8.6 ]

# %%
print(a.ndim)
# Out:
# 1

# %%
print(a.itemsize)
# Out:
# 8

# %%
print(a.dtype)
# Out:
# float64

# %%
print(a.shape)
# Out:
# (10,)

# %%
print(a[0:])
# Out:
# [9.65 8.87 8.   8.67 8.21 9.34 8.2  7.9  8.   8.6 ]

# %%
print(a.mean)
# Out:
# <built-in method mean of numpy.ndarray object at 0x000001BBC9606120>

# %%
print(a.min)
# Out:
# <built-in method min of numpy.ndarray object at 0x000001BBC9606120>

# %%
df=pd.read_csv("E:\DS\Datasets\Admission.csv")

# %%
print(df)
# Out:
#      GRE_Score  TOEFL_Score  University_Rating  SOP  LOR   CGPA  Research  \
# 0          337        118.0                  4  4.5   4.5  9.65       1.0
# 1          324        107.0                  4  4.0   4.5  8.87       1.0
# 2          316        104.0                  3  3.0   3.5  8.00       1.0
# 3          322        110.0                  3  3.5   2.5  8.67       1.0
# 4          314        103.0                  2  2.0   3.0  8.21       0.0
# 5          330        115.0                  5  4.5   3.0  9.34       1.0
# 6          321        109.0                  3  3.0   4.0  8.20       1.0
# 7          308          NaN                  2  3.0   4.0  7.90       0.0
# 8          302        102.0                  1  2.0   1.5  8.00       0.0
# 9          323        108.0                  3  3.5   3.0  8.60       0.0
# 10         325        106.0                  3  3.5   4.0  8.40       1.0
# 11         327        111.0                  4  4.0   4.5  9.00       1.0
# ...

# %%
df.head()
# Out:
#    GRE_Score  TOEFL_Score  University_Rating  SOP  LOR   CGPA  Research  \
# 0        337        118.0                  4  4.5   4.5  9.65       1.0
# 1        324        107.0                  4  4.0   4.5  8.87       1.0
# 2        316        104.0                  3  3.0   3.5  8.00       1.0
# 3        322        110.0                  3  3.5   2.5  8.67       1.0
# 4        314        103.0                  2  2.0   3.0  8.21       0.0
#
#    Chance_of_Admit
# 0              0.92
# 1              0.76
# 2              0.72
# 3              0.80
# 4              0.65

# %%
df.tail()
# Out:
#      GRE_Score  TOEFL_Score  University_Rating  SOP  LOR   CGPA  Research  \
# 495        332        108.0                  5  4.5   4.0  9.02       1.0
# 496        337        117.0                  5  5.0   5.0  9.87       1.0
# 497        330        120.0                  5  4.5   5.0  9.56       1.0
# 498        312        103.0                  4  4.0   5.0  8.43       0.0
# 499        327        113.0                  4  4.5   4.5  9.04       0.0
#
#      Chance_of_Admit
# 495              0.87
# 496              0.96
# 497              0.93
# 498              0.73
# 499              0.84

# %%
df.describe()
# Out:
#         GRE_Score  TOEFL_Score  University_Rating         SOP        LOR   \
# count  500.000000   498.000000         500.000000  500.000000  499.000000
# mean   316.472000   107.194779           3.114000    3.374000    3.481964
# std     11.295148     6.083938           1.143512    0.991004    0.925257
# min    290.000000    92.000000           1.000000    1.000000    1.000000
# 25%    308.000000   103.000000           2.000000    2.500000    3.000000
# 50%    317.000000   107.000000           3.000000    3.500000    3.500000
# 75%    325.000000   112.000000           4.000000    4.000000    4.000000
# max    340.000000   120.000000           5.000000    5.000000    5.000000
#
#              CGPA    Research  Chance_of_Admit
# count  500.000000  499.000000         500.00000
# mean     8.576440    0.561122           0.72174
# std      0.604813    0.496748           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# ...

# %%
df['CGPA'].max
# Out:
# <bound method Series.max of 0      9.65
# 1      8.87
# 2      8.00
# 3      8.67
# 4      8.21
# 5      9.34
# 6      8.20
# 7      7.90
# 8      8.00
# 9      8.60
# 10     8.40
# 11     9.00
# 12     9.10
# 13     8.00
# 14     8.20
# 15     8.30
# 16     8.70
# 17     8.00
# 18     8.80
# 19     8.50
# 20     7.90
# 21     8.40
# 22     9.50
# 23     9.70
# 24     9.80
# 25     9.60
# 26     8.80
# 27     7.50
# 28     7.20
# 29     7.30
#        ...
# 470    9.27
# 471    8.09
# 472    9.48
# 473    8.15
# 474    7.95
# 475    7.88
# 476    8.12
# 477    8.18
# 478    8.49
# 479    8.96
# 480    9.01
# 481    8.48
# 482    8.77
# 483    7.92
# 484    7.89
# 485    8.34
# 486    8.37
# 487    9.14
# 488    8.62
# 489    8.50
# 490    8.12
# 491    7.81
# 492    7.69
# 493    8.22
# 494    8.45
# 495    9.02
# 496    9.87
# 497    9.56
# 498    8.43
# 499    9.04
# Name: CGPA, Length: 500, dtype: float64>

# %%
[df['TOEFL_Score']>110]
# Out:
# [0       True
#  1      False
#  2      False
#  3      False
#  4      False
#  5       True
#  6      False
#  7      False
#  8      False
#  9      False
#  10     False
#  11      True
#  12     False
#  13     False
#  14     False
#  15     False
#  16     False
#  17     False
#  18     False
#  19     False
#  20     False
#  21      True
#  22      True
#  23      True
#  24      True
#  25      True
#  26     False
#  27     False
#  28     False
#  29     False
#         ...
#  470    False
#  471    False
#  472     True
#  473    False
#  474    False
#  475    False
#  476    False
#  477    False
#  478    False
#  479    False
#  480    False
#  481    False
#  482     True
#  483    False
#  484    False
#  485    False
#  486    False
#  487     True
#  488     True
#  489    False
#  490    False
#  491    False
#  492    False
#  493    False
#  494    False
#  495    False
#  496     True
#  497     True
#  498    False
#  499     True
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 470    False
# 471    False
# 472    False
# 473    False
# 474    False
# 475    False
# 476    False
# 477    False
# 478    False
# 479    False
# 480    False
# 481    False
# 482    False
# 483    False
# 484    False
# 485    False
# 486    False
# 487    False
# 488    False
# 489    False
# 490    False
# 491    False
# 492    False
# 493    False
# 494    False
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Length: 500, dtype: bool

# %%
df.isnull()
# Out:
#      GRE_Score  TOEFL_Score  University_Rating    SOP   LOR    CGPA  Research  \
# 0        False        False              False  False  False  False     False
# 1        False        False              False  False  False  False     False
# 2        False        False              False  False  False  False     False
# 3        False        False              False  False  False  False     False
# 4        False        False              False  False  False  False     False
# 5        False        False              False  False  False  False     False
# 6        False        False              False  False  False  False     False
# 7        False         True              False  False  False  False     False
# 8        False        False              False  False  False  False     False
# 9        False        False              False  False  False  False     False
# 10       False        False              False  False  False  False     False
# ...

# %%
df.isnull().sum()
# Out:
# GRE_Score            0
# TOEFL_Score          2
# University_Rating    0
# SOP                  0
# LOR                  1
# CGPA                 0
# Research             1
# Chance_of_Admit      0
# dtype: int64

# %%
cg=df['CGPA']

# %%
print(cg)
# Out:
# 0      9.65
# 1      8.87
# 2      8.00
# 3      8.67
# 4      8.21
# 5      9.34
# 6      8.20
# 7      7.90
# 8      8.00
# 9      8.60
# 10     8.40
# 11     9.00
# 12     9.10
# 13     8.00
# 14     8.20
# 15     8.30
# 16     8.70
# 17     8.00
# 18     8.80
# 19     8.50
# 20     7.90
# 21     8.40
# 22     9.50
# 23     9.70
# 24     9.80
# 25     9.60
# 26     8.80
# 27     7.50
# 28     7.20
# 29     7.30
#        ...
# 470    9.27
# 471    8.09
# 472    9.48
# 473    8.15
# 474    7.95
# 475    7.88
# 476    8.12
# 477    8.18
# 478    8.49
# 479    8.96
# 480    9.01
# 481    8.48
# 482    8.77
# 483    7.92
# 484    7.89
# 485    8.34
# 486    8.37
# 487    9.14
# 488    8.62
# 489    8.50
# 490    8.12
# 491    7.81
# 492    7.69
# 493    8.22
# 494    8.45
# 495    9.02
# 496    9.87
# 497    9.56
# 498    8.43
# 499    9.04
# Name: CGPA, Length: 500, dtype: float64

# %%
df.corr()
# Out:
#                    GRE_Score  TOEFL_Score  University_Rating       SOP  \
# GRE_Score           1.000000     0.826759           0.635376  0.613498
# TOEFL_Score         0.826759     1.000000           0.648671  0.644062
# University_Rating   0.635376     0.648671           1.000000  0.728024
# SOP                 0.613498     0.644062           0.728024  1.000000
# LOR                 0.523611     0.542694           0.608045  0.663383
# CGPA                0.825878     0.809892           0.705254  0.712154
# Research            0.564225     0.465566           0.427371  0.410233
# Chance_of_Admit     0.810351     0.792495           0.690132  0.684137
#
#                        LOR       CGPA  Research  Chance_of_Admit
# GRE_Score          0.523611  0.825878  0.564225          0.810351
# TOEFL_Score        0.542694  0.809892  0.465566          0.792495
# University_Rating  0.608045  0.705254  0.427371          0.690132
# ...

# %%
sns.heatmap(df.corr())

# %%
sns.distplot(df['GRE_Score'],kde=True,bins=10)

# %%
sns.countplot(x='TOEFL_Score',y=None,data=df)

# %%
sns.heatmap(data=df)

# %%
add=lambda a,b:a+b
add(24,990)
# Out:
# 1014
